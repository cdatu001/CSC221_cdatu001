# %% [markdown]
# <a href="https://colab.research.google.com/github/cdatu001/CSC221_cdatu001/blob/main/hw_2_first_day.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 13
b = 12.21
total = a + b
print(a, b, total)
# Out:
# 13 12.21 25.21

# %%
print('Type in your name:')

name = input()

print(f"hello, {name}!")
# Out:
# Type in your name:
# drei
# hello, drei!

# %%
name = input('Type in your name:')

print(f"Hello, {name}")

# %%
total = 0
n = 50
while n <= 700:
  total =total + n
  n = n + 1
  if n < 60:
    print(n, total)
    print(total)
# Out:
# 50
# 101
# 153
# 206
# 260
# 315
# 371
# 428
# 486
# 545
# 605
# 666
# 728
# 791
# 855
# 920
# 986
# 1053
# 1121
# 1190
# 1260
# 1331
# 1403
# 1476
# 1550
# 1625
# 1701
# 1778
# 1856
# 1935
# 2015
# 2096
# 2178
# 2261
# 2345
# 2430
# 2516
# 2603
# 2691
# 2780
# 2870
# 2961
# 3053
# 3146
# 3240
# 3335
# 3431
# 3528
# 3626
# 3725
# 3825
# 3926
# 4028
# 4131
# 4235
# 4340
# 4446
# 4553
# 4661
# 4770
# 4880
# 4991
# 5103
# 5216
# 5330
# 5445
# 5561
# 5678
# 5796
# 5915
# 6035
# 6156
# 6278
# 6401
# 6525
# 6650
# 6776
# 6903
# 7031
# 7160
# 7290
# 7421
# 7553
# 7686
# 7820
# 7955
# 8091
# 8228
# 8366
# 8505
# 8645
# 8786
# 8928
# 9071
# 9215
# 9360
# 9506
# 9653
# 9801
# 9950
# 10100
# 10251
# 10403
# 10556
# 10710
# 10865
# 11021
# 11178
# 11336
# 11495
# 11655
# 11816
# 11978
# 12141
# 12305
# 12470
# 12636
# 12803
# 12971
# 13140
# 13310
# 13481
# 13653
# 13826
# 14000
# 14175
# 14351
# 14528
# 14706
# 14885
# 15065
# 15246
# 15428
# 15611
# 15795
# 15980
# 16166
# 16353
# 16541
# ...

# %%
total = 0
n = 50
while n <= 700:
  total = total + n
  n = n + 1
  if n < 60:
    print(n, total)
    print(total)
